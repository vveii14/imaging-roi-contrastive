# %%
import sys, inspect
import numpy
print("Imported object:", numpy)
print("__file__:", getattr(numpy, "__file__", None))
print("type:", type(numpy))
print("sys.path[0] (current working dir):", sys.path[0])
# Out:
# Imported object: <module 'numpy' (namespace)>
# __file__: None
# type: <class 'module'>
# sys.path[0] (current working dir): /home/yrd224/anaconda3/envs/neurograph/lib/python39.zip

# %%
from importlib.metadata import version, distribution

print("version:", version("numpy"))
print("dist info path:", distribution("numpy")._path)
# Out:
# version: 2.0.2
# dist info path: /home/yrd224/anaconda3/envs/neurograph/lib/python3.9/site-packages/numpy-2.0.2.dist-info
